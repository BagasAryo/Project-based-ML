# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 186.2 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.0 kB 195.7 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 217.9 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 203.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.8 MB 2.0 MB/s eta 0:00:08
#     --------------------------------------- 0.2/15.8 MB 2.9 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/15.8 MB 4.1 MB/s eta 0:00:04
#    -- ------------------------------------- 1.0/15.8 MB 5.7 MB/s eta 0:00:03
# ...

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 1.7 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/11.6 MB 3.5 MB/s eta 0:00:04
#    -- ------------------------------------- 0.7/11.6 MB 3.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/11.6 MB 5.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/11.6 MB 6.3 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.6 MB 7.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.5/11.6 MB 7.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/11.6 MB 7.7 MB/s eta 0:00:02
#    ------------ --------------------------- 3.5/11.6 MB 7.7 MB/s eta 0:00:02
#    ------------- -------------------------- 4.1/11.6 MB 8.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
df = pd.read_csv("Tab.csv")

# %%
for i in df.index:
    print("Negara {}".format(df['Negara']))
    print("Populasi {}".format(df['Populasi']))
    print("Area {}".format(df['Area']))
    print("Ibu Kota {}".format(df['Ibukota']))
# Out:
# Negara 0    Indonesia
# 1     Malaysia
# 2    Singapura
# 3       Jepang
# 4     Thailand
# Name: Negara, dtype: object
# Populasi 0    250
# 1     25
# 2     15
# 3     60
# 4     45
# Name: Populasi, dtype: int64
# Area 0    123456
# 1      3456
# 2       456
# 3      5678
# 4       678
# Name: Area, dtype: int64
# Ibu Kota 0      Jakarta
# 1           KL
# 2    Singapura
# 3        Tokyo
# 4      Bangkok
# Name: Ibukota, dtype: object
# Negara 0    Indonesia
# 1     Malaysia
# 2    Singapura
# 3       Jepang
# 4     Thailand
# Name: Negara, dtype: object
# Populasi 0    250
# 1     25
# 2     15
# 3     60
# 4     45
# Name: Populasi, dtype: int64
# Area 0    123456
# 1      3456
# 2       456
# 3      5678
# 4       678
# Name: Area, dtype: int64
# Ibu Kota 0      Jakarta
# 1           KL
# 2    Singapura
# 3        Tokyo
# 4      Bangkok
# Name: Ibukota, dtype: object
# Negara 0    Indonesia
# 1     Malaysia
# 2    Singapura
# 3       Jepang
# 4     Thailand
# ...
